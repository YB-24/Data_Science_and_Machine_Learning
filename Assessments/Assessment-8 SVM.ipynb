# %% [markdown]
# # Support Vector Machines
# ## Exercise
#
# ## [Fraud in Wine](https://en.wikipedia.org/wiki/Wine_fraud)
#
# Wine fraud relates to the commercial aspects of wine. The most prevalent type of fraud is one where wines are adulterated, usually with the addition of cheaper products (e.g. juices) and sometimes with harmful chemicals and sweeteners (compensating for color or flavor).
#
# Counterfeiting and the relabelling of inferior and cheaper wines to more expensive brands is another common type of wine fraud.
#
# <img src="wine.jpg">
#
# ## Project Goals
#
# A distribution company that was recently a victim of fraud has completed an audit of various samples of wine through the use of chemical analysis on samples. The distribution company specializes in exporting extremely high quality, expensive wines, but was defrauded by a supplier who was attempting to pass off cheap, low quality wine as higher grade wine. The distribution company has hired you to attempt to create a machine learning model that can help detect low quality (a.k.a "fraud") wine samples. They want to know if it is even possible to detect such a difference.
#
#
# Data Source: *P. Cortez, A. Cerdeira, F. Almeida, T. Matos and J. Reis. Modeling wine preferences by data mining from physicochemical properties.
# In Decision Support Systems, Elsevier, 47(4):547-553, 2009.*
#
# ---
# ---
#
# **TASK: Your overall goal is to use the wine dataset shown below to develop a machine learning model that attempts to predict if a wine is "Legit" or "Fraud" based on various chemical features. Complete the tasks below to follow along with the project.**
#
# ---
# ---

# %% [markdown]
# ## Complete the Tasks in bold
#
# **TASK: Run the cells below to import the libraries and load the dataset.**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("wine_fraud.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality type
# 0      9.4   Legit  red
# 1      9.8   Legit  red
# ...

# %% [markdown]
# **TASK: What are the unique variables in the target column we are trying to predict (quality)?**

# %%
df['quality'].value_counts()
# Out:
# quality
# Legit    6251
# Fraud     246
# Name: count, dtype: int64

# %%
# Out:
# array(['Legit', 'Fraud'], dtype=object)

# %% [markdown]
# **TASK: Create a countplot that displays the count per category of Legit vs Fraud. Is the label/target balanced or unbalanced?**

# %%
plt.figure(figsize=(8,6),dpi=200)
sns.countplot(data=df,x='quality')
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %% [markdown]
# **TASK: Let's find out if there is a difference between red and white wine when it comes to fraud. Create a countplot that has the wine *type* on the x axis with the hue separating columns by Fraud vs Legit.**

# %%
plt.figure(figsize=(8,6),dpi=200)
sns.countplot(data=df,x='type',hue='quality')
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [markdown]
# **TASK: What percentage of red wines are Fraud? What percentage of white wines are fraud?**

# %%
red_wine = df[(df['type']=='red')]

# %%
(red_wine['quality'] == 'Fraud').sum()/red_wine['quality'].count()*100
# Out:
# 3.9399624765478425

# %%
# Out:
# Percentage of fraud in Red Wines:
# 3.9399624765478425

# %%
white_wine = df[(df['type']=='white')]
(white_wine['quality'] == 'Fraud').sum()/white_wine['quality'].count()*100
# Out:
# 3.7362188648427925

# %%
# Out:
# Percentage of fraud in White Wines:
# 3.7362188648427925

# %% [markdown]
# **TASK: Calculate the correlation between the various features and the "quality" column. To do this you may need to map the column to 0 and 1 instead of a string.**

# %%
df['target'] = df['quality'].map({'Legit':0,'Fraud':1})

# %%
df.corr(numeric_only=True)['target']
# Out:
# fixed acidity           0.021794
# volatile acidity        0.151228
# citric acid            -0.061789
# residual sugar         -0.048756
# chlorides               0.034499
# free sulfur dioxide    -0.085204
# total sulfur dioxide   -0.035252
# density                 0.016351
# pH                      0.020107
# sulphates              -0.034046
# alcohol                -0.051141
# target                  1.000000
# Name: target, dtype: float64

# %%
# Out:
# fixed acidity           0.021794
# volatile acidity        0.151228
# citric acid            -0.061789
# residual sugar         -0.048756
# chlorides               0.034499
# free sulfur dioxide    -0.085204
# total sulfur dioxide   -0.035252
# density                 0.016351
# pH                      0.020107
# sulphates              -0.034046
# alcohol                -0.051141
# Fraud                   1.000000
# Name: Fraud, dtype: float64

# %% [markdown]
# **TASK: Create a bar plot of the correlation values to Fraudlent wine.**

# %%
new = df.corr(numeric_only=True)['target'].sort_values().drop('target',axis=0)

# %%
sns.barplot(x=new.index,y=new.values)
plt.xticks(rotation=90);

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# **TASK: Create a clustermap with seaborn to explore the relationships between variables.**

# %%
sns.clustermap(df.corr(numeric_only=True),cmap='viridis')

# %% [markdown]
# ----
# ## Machine Learning Model
#
# **TASK: Convert the categorical column "type" from a string or "red" or "white" to dummy variables:**

# %%
new_df = pd.get_dummies(data=df,columns=['type'],drop_first=True,dtype=np.number)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1636: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)

# %%
new_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# **TASK: Separate out the data into X features and y target label ("quality" column)**

# %%
X = new_df.drop(['target','quality'],axis=1)

# %%
y = new_df['target']

# %% [markdown]
# **TASK: Perform a Train|Test split on the data, with a 10% test size. Note: The solution uses a random state of 101**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=101)

# %% [markdown]
# **TASK: Scale the X train and X test data.**

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# **TASK: Create an instance of a Support Vector Machine classifier. Previously we have left this model "blank", (e.g. with no parameters). However, we already know that the classes are unbalanced, in an attempt to help alleviate this issue, we can automatically adjust weights inversely proportional to class frequencies in the input data with a argument call in the SVC() call. Check out the [documentation for SVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html) online and look up what the argument\parameter is.**

# %%
from sklearn.svm import SVC

# %%
base_model = SVC()

# %%
base_model.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %% [markdown]
# **TASK: Use a GridSearchCV to run a grid search for the best C and gamma parameters.**

# %%
param_grid = {'C':[0.001,0.01,0.1,0.5,1],
             'gamma':['scale','auto'],'class_weight':['balanced',{0:1,1:2},{0:1,1:3},{0:1,1:4},{0:1,1:5}]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_svc = GridSearchCV(base_model,param_grid)

# %%
grid_svc.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.001, 0.01, 0.1, 0.5, 1],
#                          'class_weight': ['balanced', {0: 1, 1: 2},
#                                           {0: 1, 1: 3}, {0: 1, 1: 4},
#                                           {0: 1, 1: 5}],
#                          'gamma': ['scale', 'auto']})

# %%
grid_svc.best_estimator_
# Out:
# SVC(C=1, class_weight={0: 1, 1: 2})

# %%
# Out:
# GridSearchCV(estimator=SVC(class_weight='balanced'),
#              param_grid={'C': [0.001, 0.01, 0.1, 0.5, 1],
#                          'gamma': ['scale', 'auto']})

# %%
# Out:
# {'C': 1, 'gamma': 'auto'}

# %% [markdown]
# **TASK: Display the confusion matrix and classification report for your model.**

# %%
y_pred = grid_svc.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[622,   1],
#        [ 26,   1]], dtype=int64)

# %%
# Out:
# array([[ 17,  10],
#        [ 92, 531]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       623
#            1       0.50      0.04      0.07        27
#
#     accuracy                           0.96       650
#    macro avg       0.73      0.52      0.52       650
# weighted avg       0.94      0.96      0.94       650

# %%
# Out:
#               precision    recall  f1-score   support
#
#        Fraud       0.16      0.63      0.25        27
#        Legit       0.98      0.85      0.91       623
#
#     accuracy                           0.84       650
#    macro avg       0.57      0.74      0.58       650
# weighted avg       0.95      0.84      0.88       650

# %% [markdown]
# **TASK: Finally, think about how well this model performed, would you suggest using it? Realistically will this work?**

# %%
from sklearn.metrics import RocCurveDisplay,ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_estimator(grid_svc,X_test,y_test)

# %%
RocCurveDisplay.from_estimator(grid_svc,X_test,y_test)

# %% [raw]
# By looking at the model i think it is not performing well
# it is because cross validation is done on basis of accuracy
# so lets try by changing the evaluating metric

# %%
grid_svc = GridSearchCV(base_model,param_grid,scoring='recall')

# %%
grid_svc.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.001, 0.01, 0.1, 0.5, 1],
#                          'class_weight': ['balanced', {0: 1, 1: 2},
#                                           {0: 1, 1: 3}, {0: 1, 1: 4},
#                                           {0: 1, 1: 5}],
#                          'gamma': ['scale', 'auto']},
#              scoring='recall')

# %%
grid_svc.best_estimator_
# Out:
# SVC(C=0.001, class_weight='balanced')

# %%
y_pred = grid_svc.predict(X_test)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[  0, 623],
#        [  0,  27]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       623
#            1       0.04      1.00      0.08        27
#
#     accuracy                           0.04       650
#    macro avg       0.02      0.50      0.04       650
# weighted avg       0.00      0.04      0.00       650
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
ConfusionMatrixDisplay.from_estimator(grid_svc,X_test,y_test)

# %%
RocCurveDisplay.from_estimator(grid_svc,X_test,y_test)

# %% [raw]
# As we see that changing metrics is not giving us the results so using ml model to predict the
# fraud wine is not the good idea based on the chemical features we need to consider other feature
# labels depending upon the expertise in the domain
